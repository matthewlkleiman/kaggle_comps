# %%
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# Set pandas options
pd.set_option('display.width', 600)

# %%
df = pd.read_csv('resources/train.csv')

print type(df.columns)
df.columns.values
# Out:
# <class 'pandas.indexes.base.Index'>
# array(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
print df.columns[df.dtypes == 'int64'].values
# Out:
# ['Id' 'MSSubClass' 'LotArea' 'OverallQual' 'OverallCond' 'YearBuilt'
#  'YearRemodAdd' 'BsmtFinSF1' 'BsmtFinSF2' 'BsmtUnfSF' 'TotalBsmtSF'
#  '1stFlrSF' '2ndFlrSF' 'LowQualFinSF' 'GrLivArea' 'BsmtFullBath'
#  'BsmtHalfBath' 'FullBath' 'HalfBath' 'BedroomAbvGr' 'KitchenAbvGr'
#  'TotRmsAbvGrd' 'Fireplaces' 'GarageCars' 'GarageArea' 'WoodDeckSF'
#  'OpenPorchSF' 'EnclosedPorch' '3SsnPorch' 'ScreenPorch' 'PoolArea'
#  'MiscVal' 'MoSold' 'YrSold' 'SalePrice']

# %%
for i in df.columns[df.dtypes == 'int64'].values:
    df.boxplot(i)
    plt.title(i, color='gold')
    plt.ylabel(i, color='brown')
    plt.xlabel('num values', color='pink')
    plt.show()

# %%
for i in df.columns[df.dtypes == 'int64'].values:
    df.plot(kind='scatter', x=i, y='SalePrice')
    plt.title('Scatterplot of ' + i + ' and SalePrice', color='gold')
    plt.xlabel(i, color='pink')
    plt.show()
